# %%
import pandas as pd

# %%
dataset = pd.read_csv("predictions_BREXIT_False_train_False_zero.csv")
len(dataset)
# Out:
# 640

# %%
df_minone = dataset[dataset["label"]==-1]
df_zero = dataset[dataset["label"]==0]
df_one = dataset[dataset["label"]==1]

# %%
print(len(df_minone))
print(len(df_zero))
print(len(df_one))
# Out:
# 46
# 478
# 116
